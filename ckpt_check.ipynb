# %%
import torch

c = torch.load("/home/blue2959/monotonic_tts/runs/nd_aligner_vctk_v1.4_ablation_20260630-141653/checkpoints/best_epoch_recon_0.634337_epoch_20_step_101600.pth")
c = c["model"]

# %%
for x in list(c.keys()):
    print(x)
# Out:
# nd_aligner.text_encoder.out.weight
# nd_aligner.text_encoder.conv_blocks.0.conv.weight
# nd_aligner.text_encoder.conv_blocks.0.conv.bias
# nd_aligner.text_encoder.conv_blocks.0.norm.weight
# nd_aligner.text_encoder.conv_blocks.0.norm.bias
# nd_aligner.text_encoder.cond_film.cond_proj.weight
# nd_aligner.text_encoder.cond_film.cond_proj.bias
# nd_aligner.text_encoder.out_proj.weight
# nd_aligner.text_encoder.out_proj.bias
# nd_aligner.spec_encoder.input_proj.weight
# nd_aligner.spec_encoder.input_proj.bias
# nd_aligner.spec_encoder.layers.0.conv.weight
# nd_aligner.spec_encoder.layers.0.conv.bias
# nd_aligner.spec_encoder.layers.0.norm.weight
# nd_aligner.spec_encoder.layers.0.norm.bias
# nd_aligner.spec_encoder.layers.0.film.weight
# nd_aligner.spec_encoder.layers.0.film.bias
# nd_aligner.spec_encoder.layers.1.conv.weight
# nd_aligner.spec_encoder.layers.1.conv.bias
# nd_aligner.spec_encoder.layers.1.norm.weight
# nd_aligner.spec_encoder.layers.1.norm.bias
# ...
