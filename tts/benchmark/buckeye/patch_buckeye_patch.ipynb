# %%
from pathlib import Path
from praatio import textgrid

tg_path = Path("/shared/data_zfs/blue2959/Buckeye-benchmark/s01/s0101a.TextGrid")
tg = textgrid.openTextgrid(tg_path, includeEmptyIntervals=False)

print(tg.tierNames)

speaker_tier = tg.getTier("s01")
print("Number of utterances:", len(speaker_tier.entries))

for interval in speaker_tier.entries:
    print(interval.start, interval.end, interval.label)
# Out:
# ('s01', 's01 - words', 's01 - phones')
# Number of utterances: 91
# 45.155708 46.441548499999996 i'm <EXCLUDE>
# 46.441548499999996 52.673163 i've lived in columbus my entire life thirty four years um born and raised on the west side of columbus
# 56.398353 58.090248 um i'm a um
# 59.59872 65.806843 it's kind of a unique position i i guess i'm a um my job title is a senior research associate um
# 66.245583 71.587845 i received my um bachelors masters p h d and nurse practitioner all from here from o s u
# 71.744519 79.969562 and i'm working down at dodd hall in a research position i'm also a nurse practitioner down there that um sees patients in follow up and in clinic
# 80.371707 82.667104 um they sort of created the position for me
# 82.667104 84.712061 about a year ago after i had my little boy
# 90.25715 94.9681755 um working on three different um research projects with three different physicians
# ...
